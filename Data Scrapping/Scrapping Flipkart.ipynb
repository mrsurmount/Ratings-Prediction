# %% [markdown]
# ### Importing the Required Libraries:-

# %%
import selenium
from selenium import webdriver
import time
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException,InvalidArgumentException,InvalidCookieDomainException
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Opening the WebDriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# ### Giving the URL:-

# %% [markdown]
# #### Headset

# %%
url='https://www.flipkart.com/boat-rockerz-255-pro-asap-charge-upto-40-hours-playback-bluetooth-headset/product-reviews/itm569e59dc49154?pid=ACCFZ95MTQSX7NFD&lid=LSTACCFZ95MTQSX7NFDPI4HH2&marketplace=FLIPKART'
driver.get(url)

# %% [markdown]
# #### Creating Empty List for the Columns, what all I want to extract:-

# %%
Rating=[]
Full_review=[]

# %%
URL=[]

for j in range(0,3000):
    review_tags=driver.find_elements_by_xpath("//nav[@class='yFHi8N']")
    for i in review_tags:
        review_tags1=i.find_element_by_tag_name("a")
        URL.append(review_tags1.get_attribute('href'))
        
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
        time.sleep(2)

# %%
print(len(URL))
print(URL)
# Out:
# 999
# ...

# %%
List_of_url = []
for i in URL:
    if i not in List_of_url:
        List_of_url.append(i)

# %%
len(List_of_url)
# Out:
# 998

# %%
List_of_url
# Out:
# ['https://www.flipkart.com/boat-rockerz-255-pro-asap-charge-upto-40-hours-playback-bluetooth-headset/product-reviews/itm569e59dc49154?pid=ACCFZ95MTQSX7NFD&lid=LSTACCFZ95MTQSX7NFDPI4HH2&marketplace=FLIPKART&page=1',
#  'https://www.flipkart.com/boat-rockerz-255-pro-asap-charge-upto-40-hours-playback-bluetooth-headset/product-reviews/itm569e59dc49154?pid=ACCFZ95MTQSX7NFD&lid=LSTACCFZ95MTQSX7NFDPI4HH2&marketplace=FLIPKART&page=2',
#  'https://www.flipkart.com/boat-rockerz-255-pro-asap-charge-upto-40-hours-playback-bluetooth-headset/product-reviews/itm569e59dc49154?pid=ACCFZ95MTQSX7NFD&lid=LSTACCFZ95MTQSX7NFDPI4HH2&marketplace=FLIPKART&page=3',
#  'https://www.flipkart.com/boat-rockerz-255-pro-asap-charge-upto-40-hours-playback-bluetooth-headset/product-reviews/itm569e59dc49154?pid=ACCFZ95MTQSX7NFD&lid=LSTACCFZ95MTQSX7NFDPI4HH2&marketplace=FLIPKART&page=4',
# ...

# %%
#Going to the first url through our driver
driver.get(List_of_url[0])

# %%
#running a loop to extract all the required information from url
Ratings=[]
Full_review=[]
from tqdm import tqdm
for i in tqdm(List_of_url):
    driver.get(i)
    
    time.sleep(2)
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                     
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    time.sleep(2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 998/998 [1:27:18<00:00,  5.25s/it]

# %%
len(Ratings)
# Out:
# 9825

# %%
len(Full_review)
# Out:
# 9825

# %%
Ratings
# Out:
# ['5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '5',
#  '5',
#  '4',
#  '4',
#  '5',
#  '3',
#  '4',
#  '1',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '3',
#  '4',
#  '4',
#  '4',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '4',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '1',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '1',
#  '1',
#  '5',
#  '5',
#  '5',
#  '5',
#  '1',
#  '5',
#  '5',
#  '5',
#  '5',
#  '1',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '1',
#  '5',
#  '5',
#  '1',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
# ...

# %%
Full_review
# Out:
# ['1. Material Quality - Not Bad... 2. Sound Quality - Awesome... 3. Bass - Decent Quality... 4. Battery Backup - Very Good... 5. Design & Bulid Quality - Very nice... 6. Fitting - Oky Type... Overall very nice and Velue for money product... Really i love the product...🤩',
#  "Writing this review after using more than 15 days. 255F pro+ has super sound quality. Bass is decent and fair enough. Most important highlight of this headset is battery life,it's amazing. Runtime depends on usage but definitely it will give you more than any other headset. Should go for it.",
#  'One of the best Bluetooth Boat. 1- Battery Backup Amazing 2- light wait 3-Awesome Sound quality 4-Bass good 5- Design normal but good not best',
#  'Nice product and fast delivery . I am happy nice job Flipkart thanks',
# ...

# %%
df = pd.DataFrame({'Product':'Headset','Review':Full_review,'Ratings':Ratings})
df
# Out:
#       Product                                             Review Ratings
# 0     Headset  1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1     Headset  Writing this review after using more than 15 d...       5
# 2     Headset  One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3     Headset  Nice product and fast delivery . I am happy ni...       5
# 4     Headset  Delivered in 20 February.. today is 28 Februar...       4
# ...       ...                                                ...     ...
# 9820  Headset                          Build collety is not best       2
# 9821  Headset                   Good product,sound quality spr..       5
# 9822  Headset                          Value For Money Product 👍       5
# 9823  Headset  Good battery back up, decent sound, product lo...       4
# 9824  Headset           Battery 🔋 life is so long 3 days minimum       5
#
# [9825 rows x 3 columns]

# %%
url= "https://www.flipkart.com/oneplus-buds-bluetooth-headset/product-reviews/itm4b5b6de677c10?pid=ACCFTRN354PRDUUD&lid=LSTACCFTRN354PRDUUD4MLRDQ&marketplace=FLIPKART"
driver.get(url)

# %%
URL=[]

for j in range(0,325):
    review_tags=driver.find_elements_by_xpath("//nav[@class='yFHi8N']")
    for i in review_tags:
        review_tags1=i.find_element_by_tag_name("a")
        URL.append(review_tags1.get_attribute('href'))
        
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
        time.sleep(2)

# %%
print(len(URL))
print(URL)
# Out:
# 325
# ...

# %%
List_of_url = []
for i in URL:
    if i not in List_of_url:
        List_of_url.append(i)

# %%
len(List_of_url)
# Out:
# 324

# %%
List_of_url
# Out:
# ['https://www.flipkart.com/oneplus-buds-bluetooth-headset/product-reviews/itm4b5b6de677c10?pid=ACCFTRN354PRDUUD&lid=LSTACCFTRN354PRDUUD4MLRDQ&marketplace=FLIPKART&page=1',
#  'https://www.flipkart.com/oneplus-buds-bluetooth-headset/product-reviews/itm4b5b6de677c10?pid=ACCFTRN354PRDUUD&lid=LSTACCFTRN354PRDUUD4MLRDQ&marketplace=FLIPKART&page=2',
#  'https://www.flipkart.com/oneplus-buds-bluetooth-headset/product-reviews/itm4b5b6de677c10?pid=ACCFTRN354PRDUUD&lid=LSTACCFTRN354PRDUUD4MLRDQ&marketplace=FLIPKART&page=3',
#  'https://www.flipkart.com/oneplus-buds-bluetooth-headset/product-reviews/itm4b5b6de677c10?pid=ACCFTRN354PRDUUD&lid=LSTACCFTRN354PRDUUD4MLRDQ&marketplace=FLIPKART&page=4',
#  'https://www.flipkart.com/oneplus-buds-bluetooth-headset/product-reviews/itm4b5b6de677c10?pid=ACCFTRN354PRDUUD&lid=LSTACCFTRN354PRDUUD4MLRDQ&marketplace=FLIPKART&page=5',
# ...

# %%
#Going to the first url through our driver
driver.get(List_of_url[0])

# %%
#running a loop to extract all the required information from url

from tqdm import tqdm
for i in tqdm(List_of_url):
    driver.get(i)
    
    time.sleep(2)
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
         
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    time.sleep(2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 324/324 [33:49<00:00,  6.26s/it]

# %%
len(Ratings)
# Out:
# 13036

# %%
len(Full_review)
# Out:
# 13036

# %%
Ratings
# Out:
# ['5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '5',
#  '5',
#  '4',
#  '4',
#  '5',
#  '3',
#  '4',
#  '1',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '3',
#  '4',
#  '4',
#  '4',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '4',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '1',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '1',
#  '1',
#  '5',
#  '5',
#  '5',
#  '5',
#  '1',
#  '5',
#  '5',
#  '5',
#  '5',
#  '1',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '1',
#  '5',
#  '5',
#  '1',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
# ...

# %%
Full_review
# Out:
# ['1. Material Quality - Not Bad... 2. Sound Quality - Awesome... 3. Bass - Decent Quality... 4. Battery Backup - Very Good... 5. Design & Bulid Quality - Very nice... 6. Fitting - Oky Type... Overall very nice and Velue for money product... Really i love the product...🤩',
#  "Writing this review after using more than 15 days. 255F pro+ has super sound quality. Bass is decent and fair enough. Most important highlight of this headset is battery life,it's amazing. Runtime depends on usage but definitely it will give you more than any other headset. Should go for it.",
#  'One of the best Bluetooth Boat. 1- Battery Backup Amazing 2- light wait 3-Awesome Sound quality 4-Bass good 5- Design normal but good not best',
#  'Nice product and fast delivery . I am happy nice job Flipkart thanks',
# ...

# %%
df1 = pd.DataFrame({'Product':'Headset','Review':Full_review,'Ratings':Ratings})
df1
# Out:
#        Product                                             Review Ratings
# 0      Headset  1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Headset  Writing this review after using more than 15 d...       5
# 2      Headset  One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Headset  Nice product and fast delivery . I am happy ni...       5
# 4      Headset  Delivered in 20 February.. today is 28 Februar...       4
# ...        ...                                                ...     ...
# 13031  Headset                  This is what you are looking for.       5
# 13032  Headset  Excellent tws... Its a no brainer for Oneplus ...       5
# 13033  Headset                                    Nice product 👍🙂       5
# 13034  Headset                      It's amazing, guys go for it.       5
# 13035  Headset  After using a week writing this comment ok wil...       4
#
# [13036 rows x 3 columns]

# %% [markdown]
# #### Laptop

# %%
url= "https://www.flipkart.com/asus-ryzen-3-dual-core-3250u-3rd-gen-8-gb-256-gb-ssd-windows-10-home-m515da-bq322ts-thin-light-laptop/product-reviews/itm00d893dc25af4?pid=COMG6HNASNQG6XC7&lid=LSTCOMG6HNASNQG6XC7TOWQN2&marketplace=FLIPKART"
driver.get(url)

# %%
URL=[]

for j in range(0,35):
    review_tags=driver.find_elements_by_xpath("//nav[@class='yFHi8N']")
    for i in review_tags:
        review_tags1=i.find_element_by_tag_name("a")
        URL.append(review_tags1.get_attribute('href'))
        
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
        time.sleep(2)

# %%
print(len(URL))
print(URL)
# Out:
# 35
# ...

# %%
List_of_url = []
for i in URL:
    if i not in List_of_url:
        List_of_url.append(i)

# %%
len(List_of_url)
# Out:
# 34

# %%
List_of_url
# Out:
# ['https://www.flipkart.com/asus-ryzen-3-dual-core-3250u-3rd-gen-8-gb-256-gb-ssd-windows-10-home-m515da-bq322ts-thin-light-laptop/product-reviews/itm00d893dc25af4?pid=COMG6HNASNQG6XC7&lid=LSTCOMG6HNASNQG6XC7TOWQN2&marketplace=FLIPKART&page=1',
#  'https://www.flipkart.com/asus-ryzen-3-dual-core-3250u-3rd-gen-8-gb-256-gb-ssd-windows-10-home-m515da-bq322ts-thin-light-laptop/product-reviews/itm00d893dc25af4?pid=COMG6HNASNQG6XC7&lid=LSTCOMG6HNASNQG6XC7TOWQN2&marketplace=FLIPKART&page=2',
#  'https://www.flipkart.com/asus-ryzen-3-dual-core-3250u-3rd-gen-8-gb-256-gb-ssd-windows-10-home-m515da-bq322ts-thin-light-laptop/product-reviews/itm00d893dc25af4?pid=COMG6HNASNQG6XC7&lid=LSTCOMG6HNASNQG6XC7TOWQN2&marketplace=FLIPKART&page=3',
#  'https://www.flipkart.com/asus-ryzen-3-dual-core-3250u-3rd-gen-8-gb-256-gb-ssd-windows-10-home-m515da-bq322ts-thin-light-laptop/product-reviews/itm00d893dc25af4?pid=COMG6HNASNQG6XC7&lid=LSTCOMG6HNASNQG6XC7TOWQN2&marketplace=FLIPKART&page=4',
# ...

# %%
#Going to the first url through our driver
driver.get(List_of_url[0])

# %%
#running a loop to extract all the required information from url
from tqdm import tqdm
for i in tqdm(List_of_url):
    driver.get(i)
    
    time.sleep(2)
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                     
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    time.sleep(2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 34/34 [02:55<00:00,  5.15s/it]

# %%
len(Ratings)
# Out:
# 13395

# %%
len(Full_review)
# Out:
# 13395

# %%
df2 = pd.DataFrame({'Product':'Laptop','Review':Full_review,'Ratings':Ratings})
df2
# Out:
#       Product                                             Review Ratings
# 0      Laptop  1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Laptop  Writing this review after using more than 15 d...       5
# 2      Laptop  One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Laptop  Nice product and fast delivery . I am happy ni...       5
# 4      Laptop  Delivered in 20 February.. today is 28 Februar...       4
# ...       ...                                                ...     ...
# 13390  Laptop        Except battery and sound, everything is ok.       3
# 13391  Laptop                                 Value for money 👍🔥       4
# 13392  Laptop                                              super       5
# 13393  Laptop  1. Performance is good in this price value  2....       4
# 13394  Laptop  Perfect okay 😍maximum benefit @low cost Accoun...       5
#
# [13395 rows x 3 columns]

# %%
df2.drop(['Product'],axis = 1,inplace = True)
df2
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 13390        Except battery and sound, everything is ok.       3
# 13391                                 Value for money 👍🔥       4
# 13392                                              super       5
# 13393  1. Performance is good in this price value  2....       4
# 13394  Perfect okay 😍maximum benefit @low cost Accoun...       5
#
# [13395 rows x 2 columns]

# %%
url='https://www.flipkart.com/apple-2020-macbook-air-m1-8-gb-256-gb-ssd-mac-os-big-sur-mgn63hn-a/product-reviews/itmde54f026889ce?pid=COMFXEKMGNHZYFH9&lid=LSTCOMFXEKMGNHZYFH9P56X45&marketplace=FLIPKART'
driver.get(url)

# %%
for i in range(0,62): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
            
          
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    time.sleep(1)
    button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 14015

# %%
len(Full_review)
# Out:
# 14006

# %%
Ratings = Ratings[0:14006]
Full_review = Full_review[0:14006]

# %%
df3 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df3
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 14001                                       It's so good       5
# 14002                                  A hulk in itself.       5
# 14003  Great product. Build quality is phenomenal, pe...       5
# 14004                                       Awesome!!!!!       5
# 14005  Best tech from Apple. Thank you Flipkart for o...       5
#
# [14006 rows x 2 columns]

# %%
url='https://www.flipkart.com/lenovo-ideapad-s145-ryzen-3-dual-core-3200u-4-gb-1-tb-hdd-windows-10-home-s145-15api-thin-light-laptop/product-reviews/itm3028b196c8fe1?pid=COMFJM3T7ZF2Z86F&lid=LSTCOMFJM3T7ZF2Z86FUWBWK9&marketplace=FLIPKART'
driver.get(url)

# %%
for i in range(0,85): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 14855

# %%
len(Full_review)
# Out:
# 14855

# %%
df4 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df4
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 14850  As of now everythink seems to be ok. Delivery ...       5
# 14851                Worth every penny .Fully satisfied.       5
# 14852                   Very good product.worth ot money       5
# 14853  I don't know why peoples are saying that it's ...       4
# 14854                   good product and value for price       5
#
# [14855 rows x 2 columns]

# %% [markdown]
# #### Phones

# %%
url='https://www.flipkart.com/samsung-galaxy-s20-fe-cloud-navy-256-gb/product-reviews/itm41ba0b2b96c2c?pid=MOBGDWA9TCHEFUPG&lid=LSTMOBGDWA9TCHEFUPGLPKEJR&marketplace=FLIPKART'
driver.get(url)

# %%
for i in range(0,10): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 14955

# %%
len(Full_review)
# Out:
# 14955

# %%
df5 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df5
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 14950                   Battery is very fast overheating       1
# 14951                                          Very good       4
# 14952               I would say really impressive phone.       5
# 14953  The camera quality is awesome. Build quality i...       4
# 14954                   Worthy Buy ..Extremely Satisfied       5
#
# [14955 rows x 2 columns]

# %%
url = "https://www.flipkart.com/redmi-note-8-pro-halo-white-64-gb/product-reviews/itm4da816cb9b194?pid=MOBFHHRRUJSYKJGQ&lid=LSTMOBFHHRRUJSYKJGQNF1RGW&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,695): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 27914

# %%
len(Full_review)
# Out:
# 27914

# %%
df6 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df6
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 27909                                              Happy       5
# 27910                                nice one .I like it       4
# 27911  GOOD CAMERA,SUPERB DISPLAY,SMOOTH RUNNING,LONG...       5
# 27912                                          excellent       5
# 27913                                               goof       5
#
# [27914 rows x 2 columns]

# %% [markdown]
# #### Smart-Watches

# %%
url = "https://www.flipkart.com/noise-colorfit-qube-spo2-smartwatch/product-reviews/itm2d9dc41a02202?pid=SMWG6RB5FX7RXWZ8&lid=LSTSMWG6RB5FX7RXWZ8MROVKI&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,435): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 32145

# %%
len(Full_review)
# Out:
# 32145

# %%
df7 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df7
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 32140                                       Nice product       5
# 32141                                       Best product       4
# 32142              Value for money purchase during FBBD.       5
# 32143                        Battery backup is very poor       1
# 32144                                    Value for money       4
#
# [32145 rows x 2 columns]

# %%
url = "https://www.flipkart.com/dizo-watch-2-sports-by-realme-techlife/product-reviews/itmd60e8b0020067?pid=SMWGBEY7TQP8URVH&lid=LSTSMWGBEY7TQP8URVHIMRYVD&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,210): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 34052

# %%
len(Full_review)
# Out:
# 34052

# %%
df8 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df8
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 34047  The most beautiful watch and very useful full ...       5
# 34048                              Best watch under 2k❤️       4
# 34049                       This watch look is oosoomm😍😍       5
# 34050                                  Best i love it ❤🙄       4
# 34051                                       It's awesome       5
#
# [34052 rows x 2 columns]

# %% [markdown]
# #### Professional Cameras

# %%
url = "https://www.flipkart.com/canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens/product-reviews/itm6f665fea97bc2?pid=CAMF3DHJURPEMNRN&lid=LSTCAMF3DHJURPEMNRNEB3BV2&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,363): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 37674

# %%
len(Full_review)
# Out:
# 37674

# %%
df9 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df9
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 37669                                           Niceeeee       4
# 37670                                    Not Much bettet       1
# 37671                                               best       5
# 37672                                super at this price       4
# 37673                                           good one       5
#
# [37674 rows x 2 columns]

# %%
url = "https://www.flipkart.com/canon-eos-1500d-dslr-camera-body-18-55-mm-ii-lens/product-reviews/itm033175ceb4ddd?pid=DLLFAEWE22ZAERXG&lid=LSTDLLFAEWE22ZAERXGAHOJFJ&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,182): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 39493

# %%
len(Full_review)
# Out:
# 39493

# %%
df10 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df10
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 39488                                               nice       5
# 39489                                     awesome camera       5
# 39490                                       good product       5
# 39491  camera 📸 is awesome but packaging 📦 was not go...       4
# 39492  my first DSLR awesome it s picture quality I l...       5
#
# [39493 rows x 2 columns]

# %% [markdown]
# #### Printers

# %%
url = "https://www.flipkart.com/canon-g3012-multi-function-wifi-color-printer-color-page-cost-0-21-rs-black-0-09-borderless-printing/product-reviews/itmf2qc6hhx4pkua?pid=PRNF2QC6BX5M9NAJ&lid=LSTPRNF2QC6BX5M9NAJGZLEW6&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,95): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 40435

# %%
len(Full_review)
# Out:
# 40435

# %%
df11 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df11
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 40430              Awesome printer, working great so far       5
# 40431                             This is price for good       5
# 40432                                    Awesome product       5
# 40433                                     Best under 13k       4
# 40434                        Amazing working efficiently       5
#
# [40435 rows x 2 columns]

# %%
url = "https://www.flipkart.com/canon-mg2570s-multi-function-color-printer-color-page-cost-9-rs-black-7-rs/product-reviews/itme8pd6c9gcente?pid=PRNE8PD6M53KZZXA&lid=LSTPRNE8PD6M53KZZXAZEUAHX&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,685): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 47268

# %%
len(Full_review)
# Out:
# 47268

# %%
df12 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df12
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 47263  from existing catridge we use upto 40 copies, ...       1
# 47264  Received the product on 5th April Called flipk...       1
# 47265  This Printer Just prints 100 page at a time.Al...       1
# 47266  Very bad product...........very frustrating pr...       1
# 47267  Prompt delivery and product exactly as describ...       4
#
# [47268 rows x 2 columns]

# %% [markdown]
# #### Monitors

# %%
url = "https://www.flipkart.com/lg-24-inch-full-hd-led-backlit-ips-panel-white-colour-monitor-24mk600m/product-reviews/itmfb6jq2jgffrtj?pid=MONFB6JQFJEP7BZX&lid=LSTMONFB6JQFJEP7BZXLEIFM1&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,101): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 48277

# %%
len(Full_review)
# Out:
# 48277

# %%
df13 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df13
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 48272  as for now everything is just great,, great mo...       5
# 48273                         Good product give it a try       5
# 48274  LG is my favorite company And this product is ...       4
# 48275  Very awesome monitor... View angle quality exc...       4
# 48276                        It's monitor is fantastic..       5
#
# [48277 rows x 2 columns]

# %%
url = "https://www.flipkart.com/acer-21-5-inch-full-hd-ips-panel-white-colour-monitor-ha220q/product-reviews/itmfdfdjxg7gdzpf?pid=MONFDFDJVFMGY9NV&lid=LSTMONFDFDJVFMGY9NVV7ABPJ&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,101): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 48933

# %%
len(Full_review)
# Out:
# 48933

# %%
df14 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df14
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 48928                                    Looking SO good       5
# 48929                                    Looking SO good       5
# 48930                                    Looking SO good       5
# 48931                                    Looking SO good       5
# 48932                                    Looking SO good       5
#
# [48933 rows x 2 columns]

# %% [markdown]
# #### Home Theater

# %%
url = "https://www.flipkart.com/sony-sa-d40-80-w-bluetooth-home-theatre/product-reviews/itmfy95dvfgcbnsd?pid=ACCFY95D3FRZTWH5&lid=LSTACCFY95D3FRZTWH5WA1KBC&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,420): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 53114

# %%
len(Full_review)
# Out:
# 53114

# %%
df15 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df15
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 53109      Awesome product by sony. But no bass control.       5
# 53110  Nice product for this price. I love this super...       5
# 53111                                             v good       5
# 53112                                               good       5
# 53113                     FABULOUS PRODUCT OF THIS RANGE       5
#
# [53114 rows x 2 columns]

# %%
url = "https://www.flipkart.com/intex-it-2616-bt-55-w-bluetooth-home-theatre/product-reviews/itm1338b5084a829?pid=ACCFNMEYJNHSNCWN&lid=LSTACCFNMEYJNHSNCWNXWFCRW&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,368): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 61535

# %%
len(Full_review)
# Out:
# 61535

# %%
df16 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df16
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 61530   Good quality in low price...best home theater 🧡🍹       5
# 61531                                       Nice product       5
# 61532                                              Sorry       5
# 61533                                            Awesome       5
# 61534     It good product and sound clarity is very good       5
#
# [61535 rows x 2 columns]

# %% [markdown]
# #### Router

# %%
url = "https://www.flipkart.com/tp-link-tl-wr841n-300mbps-wireless-n-router/product-reviews/itmf48vgyfyx8m4f?pid=RTRD7HN3JJYF6WN2&lid=LSTRTRD7HN3JJYF6WN2K7AOMM&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,1175): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 78255

# %%
len(Full_review)
# Out:
# 78255

# %%
df17 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df17
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 78250  Very good connectivity at very good price! All...       4
# 78251  I bought this router 2 weeks ago. Set Up was e...       4
# 78252  After using the product for 2 days, i can say ...       5
# 78253  Delivery was superb from Flipkart within 24hou...       4
# 78254  I have been using the router for past 6 days, ...       4
#
# [78255 rows x 2 columns]

# %%
url = "https://www.flipkart.com/d-link-dir-819-750-mbps-wireless-router/product-reviews/itmff2hynmhzhtqa?pid=RTRFF2HYYUYHCGGK&lid=LSTRTRFF2HYYUYHCGGKB3BKOG&marketplace=FLIPKART"
driver.get(url)

# %%
for i in range(0,580): 
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq']"):
        Ratings.append(j.text)
                  
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        Full_review.append(k.text.replace('\n',' '))
    
    try:
        button=driver.find_element_by_xpath("//nav[@class='yFHi8N']//*[contains(text(), 'Next')]")
        driver.execute_script("arguments[0].click();", button)
    except NoSuchElementException:
        pass
    time.sleep(2)

# %%
len(Ratings)
# Out:
# 84035

# %%
len(Full_review)
# Out:
# 84035

# %%
df18 = pd.DataFrame({'Review':Full_review,'Ratings':Ratings})
df18
# Out:
#                                                   Review Ratings
# 0      1. Material Quality - Not Bad... 2. Sound Qual...       5
# 1      Writing this review after using more than 15 d...       5
# 2      One of the best Bluetooth Boat. 1- Battery Bac...       5
# 3      Nice product and fast delivery . I am happy ni...       5
# 4      Delivered in 20 February.. today is 28 Februar...       4
# ...                                                  ...     ...
# 84030  This is pretty good wifi-router. I havent seen...       5
# 84031                                               Good       5
# 84032                                          excellent       5
# 84033                                       good product       3
# 84034                                       Useless item       1
#
# [84035 rows x 2 columns]

# %%
df18.to_csv("RatingsandReviews.csv")
